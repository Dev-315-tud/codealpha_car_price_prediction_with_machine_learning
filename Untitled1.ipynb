# %% [markdown]
# CODEALPHA TASK THIRD  CAR PRICE PREDICTION

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("car data.CSV")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    148
# Driven_kms       206
# Fuel_Type          3
# Selling_type       2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df['Present_Price'].unique
# Out:
# <bound method Series.unique of 0       5.59
# 1       9.54
# 2       9.85
# 3       4.15
# 4       6.87
#        ...
# 296    11.60
# 297     5.90
# 298    11.00
# 299    12.50
# 300     5.90
# Name: Present_Price, Length: 301, dtype: float64>

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0      2014
# 1      2013
# 2      2017
# 3      2011
# 4      2014
#        ...
# 296    2016
# 297    2015
# 298    2009
# 299    2017
# 300    2016
# Name: Year, Length: 301, dtype: int64>

# %%
df['Selling_Price'].unique
# Out:
# <bound method Series.unique of 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64>

# %% [markdown]
# DATA VISUALIZATION

# %%
plt.rcParams.update({'font.size': 20}) 

fig, ax = plt.subplots(figsize=(20, 10), layout='constrained' )

# Assuming both Series have the same length
ax.plot(df.index, df['Selling_Price'], label='Selling Price', color='brown',marker='v')


ax.set_xlabel('Index' ,fontsize= 20 , color='black' )
ax.set_ylabel('Price' ,fontsize= 20 , color='black')
ax.set_title('Selling Price Trend ' ,fontsize= 20 , color='black')
ax.legend()
plt.show()

# %%
plt.rcParams.update({'font.size': 20}) 

fig, ax = plt.subplots(figsize=(20, 10), layout='constrained' )

# Assuming both Series have the same length

ax.plot(df.index, df['Present_Price'], label='Present Price', color='green',marker='s')

ax.set_xlabel('Index' ,fontsize= 20 , color='black' )
ax.set_ylabel('Price' ,fontsize= 20 , color='black')
ax.set_title(' Present Price Trend ' ,fontsize= 20 , color='black')
ax.legend()
plt.show()

# %%
plt.rcParams.update({'font.size': 20}) 

fig, ax = plt.subplots(figsize=(20, 10), layout='constrained' )

# Assuming both Series have the same length
ax.plot(df.index, df['Selling_Price'], label='Selling Price', color='brown', marker='v')
ax.plot(df.index, df['Present_Price'], label='Present Price', color='green',marker='s')

ax.set_xlabel('Index' ,fontsize= 20 , color='black' )
ax.set_ylabel('Price' ,fontsize= 20 , color='black')
ax.set_title('Selling vs Present Price Trend ' ,fontsize= 20 , color='black')
ax.legend()
plt.show()

# %% [markdown]
# <!-- MODEL TRAINING -->

# %% [markdown]
# MODEL TRAINING

# %%
#Machine_learning_library
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

# %%
x=df.drop(['Selling_Price','Car_Name','Fuel_Type','Selling_type','Transmission'] ,axis=1)
x
# Out:
#      Year  Present_Price  Driven_kms  Owner
# 0    2014           5.59       27000      0
# 1    2013           9.54       43000      0
# 2    2017           9.85        6900      0
# 3    2011           4.15        5200      0
# 4    2014           6.87       42450      0
# ..    ...            ...         ...    ...
# 296  2016          11.60       33988      0
# 297  2015           5.90       60000      0
# 298  2009          11.00       87934      0
# 299  2017          12.50        9000      0
# 300  2016           5.90        5464      0
#
# [301 rows x 4 columns]

# %%
y=df['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2 , random_state=42)

# %%
x_train
# Out:
#      Year  Present_Price  Driven_kms  Owner
# 184  2008          0.750       26000      1
# 132  2017          0.950        3500      0
# 194  2008          0.787       50000      0
# 75   2015          6.800       36000      0
# 111  2016          1.500        8700      0
# ..    ...            ...         ...    ...
# 188  2013          0.570       18000      0
# 71   2011         12.480       45000      0
# 106  2014          3.450       16500      1
# 270  2011         10.000       69341      0
# 102  2017          1.780        4000      0
#
# [240 rows x 4 columns]

# %%
x_test
# Out:
#      Year  Present_Price  Driven_kms  Owner
# 177  2016           0.57       24000      0
# 289  2016          13.60       10980      0
# 228  2012           9.40       60000      0
# 198  2011           0.57       35000      1
# 60   2013          18.61       40001      0
# ..    ...            ...         ...    ...
# 234  2015           5.70        4492      0
# 296  2016          11.60       33988      0
# 281  2006           7.60       50456      0
# 285  2016           8.50       15059      0
# 182  2013           0.58       30000      0
#
# [61 rows x 4 columns]

# %%
y_train
# Out:
# 184    0.25
# 132    0.75
# 194    0.20
# 75     3.95
# 111    1.15
#        ...
# 188    0.25
# 71     4.50
# 106    1.35
# 270    4.10
# 102    1.65
# Name: Selling_Price, Length: 240, dtype: float64

# %%
y_test
# Out:
# 177     0.35
# 289    10.11
# 228     4.95
# 198     0.15
# 60      6.95
#        ...
# 234     5.50
# 296     9.50
# 281     2.10
# 285     7.40
# 182     0.30
# Name: Selling_Price, Length: 61, dtype: float64

# %%
#Linear Regression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %% [markdown]
# #MODEL_PREDICTION

# %%
#Linear Regression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
print("linear Regression,Prediction:",y_pred)

modelp = model.score(x_test, y_test)  
acc = f"Linear  Regression model accuracy : {modelp * 100:.2f}%"
acc
# Out:
# linear Regression,Prediction: [ 2.10916346  8.84523135  4.95054983 -1.14759662 10.14230184  5.981295
#   2.15090534  1.44132638  2.10250345  6.0895694   7.7493921   1.30279026
#   7.19465357  2.51919518  5.38475327  3.03998004  1.0452927  11.86927839
#   2.52823727  3.19517764  0.93941504  6.67021791  4.97496881  2.28893765
#   1.48309738  3.62562561  5.63247228  2.64022668  3.00607845  2.59441556
#   0.96530285  8.16383105 -0.22318912  2.1072456   7.36678419  4.57594267
#   8.08585858  8.43901454  2.79901137  8.83444531  4.20969177  3.03893702
#   4.28040801  1.37520388  5.82919438  1.1643297   7.9775779  11.02198021
#   2.92078149  3.61051086  5.39251886  3.01216599 19.93213223 15.34729053
#   6.2122404   8.82778656  4.35291824  7.79276349  1.50420002  6.20960172
#   0.84612182]
# 'Linear  Regression model accuracy : 82.09%'
